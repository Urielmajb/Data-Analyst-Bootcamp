# %% [markdown]
# # Comparison Operators
#
# ![Captura de pantalla 2024-09-14 221149.png](attachment:122b07dc-2861-4867-911e-137236bbc3ad.png)

# %%
50 == 50
# Out:
# False

# %%
10 != 50
# Out:
# True

# %%
'Vanilla' == 'Chocolate'
# Out:
# False

# %%
10 <= 50
# Out:
# True

# %%
10 >= 50
# Out:
# False

# %% [markdown]
# # Logical Operators
#
# ![2222.png](attachment:9c52f063-e5de-4401-9c2d-cbf46a507855.png)

# %%
(70 > 50) and (50>10)
# Out:
# True

# %%
(70 > 50) or (50>10)
# Out:
# True

# %%
('Vanilla' > 'Chocolate') and (50>10)
# Out:
# True

# %%
not(50>10)
# Out:
# False

# %% [markdown]
# # Membership Operators
#
# ![5000.png](attachment:19c053c1-89d2-42ea-a14a-221f3d1c11c3.png)

# %%
ice_cream = 'I love chocolate ice cream'

'love' in 'I love chocolate ice cream'
# Out:
# True

# %%
scoops = [1,2,3,4,5]

6 in scoops
# Out:
# False
