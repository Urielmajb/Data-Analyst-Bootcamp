# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://en.wikipedia.org/wiki/List_of_songs_recorded_by_Lana_Del_Rey'
page= requests.get(url)

# %%
soup = BeautifulSoup(page.text, 'html')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of songs recorded by Lana Del Rey - Wikipedia
#   </title>
#   <script>
# ...

# %%
table = soup.find_all('table')[2]
print(table)
# Out:
# <table class="wikitable sortable plainrowheaders" style="text-align:center;">
# <tbody><tr>
# <th>Title
# </th>
# <th>Artist(s)
# </th>
# <th class="unsortable">Writer(s)
# </th>
# <th>Album(s)
# </th>
# <th>Year
# </th>
# <th class="unsortable"><abbr title="Reference(s)">Ref.</abbr>
# </th></tr>
# <tr>
# <th scope="row"><span class="anchor" id="#"></span> "13 Beaches"
# </th>
# <td><span data-sort-value="Del Rey, Lana !">Lana Del Rey</span>
# </td>
# <td>Lana Del Rey<br/>Rick Nowels
# </td>
# <td><i>Lust for Life</i>
# </td>
# <td><span data-sort-value="2017-1 !">2017</span>
# </td>
# <td><sup class="reference" id="cite_ref-autogenerated1_13-0"><a href="#cite_note-autogenerated1-13"><span class="cite-bracket">[</span>13<span class="cite-bracket">]</span></a></sup>
# </td></tr>
# <tr>
# <th scope="row">"24"
# </th>
# <td><span data-sort-value="Del Rey, Lana !">Lana Del Rey</span>
# </td>
# <td>Lana Del Rey<br/><a href="/wiki/Rick_Nowels" title="Rick Nowels">Rick Nowels</a>
# </td>
# ...

# %%
headers = [header.text.strip() for header in table.find_all('th')]

# %%
desired_headers = ['Title', 'Artist(s)', 'Writer(s)', 'Album(s)', 'Year']
filtered_headers = [header for header in headers if header in desired_headers]

print(filtered_headers)
# Out:
# ['Title', 'Artist(s)', 'Writer(s)', 'Album(s)', 'Year']

# %%
import pandas as pd

# %%
df= pd.DataFrame(columns = filtered_headers)

# %%
column_table = table.find_all('tr')

# %%
for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    
    length = len(df)
    df.loc[length] = individual_row_data

# %%
df
# Out:
#             Title                              Artist(s)  \
# 0    Lana Del Rey                Lana Del ReyRick Nowels
# 1    Lana Del Rey                Lana Del ReyRick Nowels
# 2    Lana Del Rey       Lana Del ReyJack AntonoffSam Dew
# 3    Lana Del Rey    Lana Del ReyRick NowelsEmile Haynie
# 4    Lana Del Rey              Lana Del ReyDrew Erickson
# ..            ...                                    ...
# 508  Lana Del Rey                Lana Del ReyRick Nowels
# 509  Lana Del Rey          Tim Rice  Andrew Lloyd Webber
# 510  Lana Del Rey  Richard Rodgers  Oscar Hammerstein II
# 511  Lana Del Rey                Lana Del ReyRick Nowels
# 512  Lana Del Rey                Lana Del ReyRick Nowels
#
#                                              Writer(s) Album(s)      Year
# 0                                        Lust for Life     2017      [13]
# 1                                            Honeymoon     2015      [14]
# ...

# %%
df.to_csv(r'C:\Users\uriel\Escritorio\Bootcamp Data Analyst\Python\Lanadelrey.csv', index = False)
