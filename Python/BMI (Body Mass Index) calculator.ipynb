# %% [markdown]
# # Creacion de una calculadora BMI (Body Mass Index)

# %% [markdown]
# ![Captura de pantalla 2024-09-16 015801.png](attachment:4cd06468-9d21-4681-8616-b8504fb8c91a.png)

# %%
name= input("Enter your name: ")
weight = float(input("Enter your weight in kilograms: "))

height = float(input("Enter your height in meters: "))

bmi = (weight) / (height*height)
print(round(bmi))

if bmi > 0:
    if(bmi < 18.5):
        print(name + ", You are underweight!")
    elif(bmi <= 24.9):
        print(name + ", You are in normal weight!")
    elif(bmi < 29.9):
        print(name + ", You are overweight!")
    elif(bmi <= 30):
        print(name + ", You are obese!")
    else:
        print(name + ", You are in other level ")
else:
    print("Enter valid input: ")
# Out:
# Enter your name:  uri
# Enter your weight in kilograms:  72.57
# Enter your height in meters:  1.778
# 23
# uri, You are in normal weight!

# %% [markdown]
# ![bmi.png](attachment:49d37f6b-33ed-481c-91fe-6ec2ece8cd86.png)

# %%
# Out:
# uri, You are underweight!
